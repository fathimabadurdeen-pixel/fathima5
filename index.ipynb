# %% [markdown]
# <a href="https://colab.research.google.com/github/fathimabadurdeen-pixel/fathima5/blob/main/index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Control Flow: Conditionals
#
# Conditionals are statements in programming that let your code make decisions.
# They allow Python to execute certain blocks of code only if a specified condition is True.
#
# Think of it like everyday “if-then” logic:
#
# “If it rains, then take an umbrella. Otherwise, wear sunglasses.”

# %% [markdown]
# ### Types of Conditional Statements
#
# Python has three main conditional statements:

# %% [markdown]
# ### a) if
#
# Executes a block of code only if the condition is True.
#
# Syntax:
#
# ```python
# if condition:
#     # code block runs if condition is True
# ```

# %%
if 100 > 10:
    print("100 is greater than 10")
# Out:
# 100 is greater than 10

# %%
if True:
   print ('i Run')
# Out:
# i Run

# %%
if True:
    print ('i wont Run')
# Out:
# i wont Run

# %%
if False:
    print ('i Run')

# %%
print ('the End')
  print
# Out:
#   File "/tmp/ipython-input-4287277438.py", line 2
#     print
#     ^
# IndentationError: unexpected indent

# %%
canvas_hours = 9
if canvas_hours > 10:
  print('Good job')
  print

# %%
if canvas_hours > 10 and attempted_checkpoint:
  print('awesome')
  print

# %%
gender = 'F'
if gender == 'M':
    print ('hello sir')
else:
    print('Hello Madam')
# Out:
# Hello Madam

# %%
gender = 'cow'

# %%
gender = 'cow'
if gender == 'M':
    print ('hello sir')
else:
    print('Hello Madam')
# Out:
# Hello Madam

# %%
religion = 'M'
if religion == 'M':
    print ('Muslim')
else:
    print('Christian')
# Out:
# Muslim

# %% [markdown]
# ### b) else
#
# - Executes a block of code if the if condition is False.
#
# - Syntax:
#
# ```python
#
# if condition:
#     # runs if True
# else:
#     # runs if False
# ```

# %% [markdown]
# ### c) elif (else if)
#
# Used when there are multiple conditions to check.
#
# Python checks conditions in order; the first True condition runs, the rest are skipped.
#
# Syntax:
#
# ```python
# if condition1:
#     # code
# elif condition2:
#     # code
# elif condition3:
#     # code
# else:
#     # code if none above are True
#
# ```

# %%
gender = 'cow'
if gender == 'M':
    print ('hello sir')
elif gender == 'F':
    print('Hello Madam')
else:
    print ('Hello', gender)
# Out:
# Hello cow

# %%
# create a grade assignment mini programme
# define variable grdae
# use conditionals to assign grade
# e.g score = 70 output = B
# 90 - 100 -> A
# 80 - 89 -> B
# 70 - 79 -> C
# 60 - 69 -> D
# < 59 -> Fail

grade = 90 - 100
if grade <= 90 - 100:
    print ('A')
if grade <= 80 - 89:
    print ('B')
if grade <= 70 - 79:
    print ('C')
if grade <= 60 - 69:
    print ('D')
if grade > 59:
    print ('Fail')
# Out:
# A
# B
# C
# D

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Truthiness and Falsiness
#
# Python allows any value to be treated as True or False in a conditional:
#
# **Falsy values (considered False)**
#
#     0 (zero)
#
#     "" (empty string)
#
#     [] (empty list)
#
#     None (missing value)
#
# **Truthy values (considered True)**
#
#     Non-zero numbers
#
#     Non-empty strings/lis

# %%
# example
if '''':
    print('this action wont run')
else:
    print('False')
# Out:
#   File "/tmp/ipython-input-3768223185.py", line 2
#     if '''':
#        ^
# SyntaxError: incomplete input

# %% [markdown]
# Truthful

# %%
# add example as above none empty values
list = [1]
if list:
    print('this action runs')
# Out:
# this action runs

# %%
True + True + True - False
# Out:
# 3

# %%
False - True
# Out:
# -1

# %% [markdown]
# ## Blocks and Indentation
#
# Blocks are groups of code that belong together under a condition.
#
# Indentation (4 spaces)(1 tab) is required to define a block.

# %%
# example
if True:
  print('am here')
  print('am here')
  print('am here')
  print('am here')
  print('am here')
  # block end
print ('last')
# Out:
# am here
# am here
# am here
# am here
# am here
# last

# %%
# example
if True:
  print('am here')
# Out:
# am here
